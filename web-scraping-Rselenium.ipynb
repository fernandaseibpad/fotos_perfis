# %% [markdown]
# <h1 style="color:slateblue;font-family:courier;">Web Scraping da Plataforma Sucupira dos Trabalhos de Conclusão Pós-Graduação</h1>
#
# <h2 style="color:slateblue;font-family:courier;">Preenchendo formulário:</h2>
#
# <ul style="font-size:20px;font-family:courier;">
#     <li>Anos: <b>2017 a 2020</b>;</li>
#     <li>Instituição de Ensino Superior: <b>UNIVERSIDADE FEDERAL DA BAHIA (UFBA)</b>;</li>
#     <li>Programa: <b>Ciência da Computação (28001010095P3)</b>.</li>
# </ul>

# %%
library(RSelenium)

# %%
url = 'https://sucupira.capes.gov.br/sucupira/public/consultas/coleta/trabalhoConclusao/listaTrabalhoConclusao.xhtml'

# %%
# start a chrome browser
rD = rsDriver(browser = "chrome", port = 4444L, geckover = NULL, 
               chromever =  "latest", iedrver = NULL, phantomver = NULL)

# %%
remDr = rD$client 
remDr$navigate(url)

# %%
source('web-scraping-rselenium.R')

# %%
#Funcao gera.dataset implementada no arquivo web-scraping-rselenium.R
dados.pgcomp.chrome = gera.dataset()

# %% [markdown]
# <h2 style="color:slateblue;font-family:courier;">Tables HTML convertidas em um único data.frame resultante das consultas realizadas:</h2>

# %%
dados.pgcomp.chrome
# Out:
#     NM_PRODUCAO
# 1   PLAR - UMA TECNICA PARA RECUPERAÇÃO DE ARQUITETURA DE LINHAS DE PRODUTO DE SOFTWARE
# 2   iSim: uma estratégia de agrupamento de usuários para descarregamento de dados em Redes Móveis Centradas na informação
# 3   Predição do Desfecho Clínico por Leptospirose Baseado na Análise de Expressão Gênica em Casos Hospitalizados
# 4   Fusão de Imagens 2d, 3d e Nir para Autenticação Facial Contínua utilizando Sensores de Baixo Custo
# 5   Procedimentos didáticos em Computação e sua relação com as características psicológicas dos estudantes: uma investigação no ensino de Teoria da Computação
# 6   BlinGui: Sistema Vestível de Detecção de Obstáculos Estáticos para Apoiar a Locomoção de Portadores de Deficiência Visual
# 7   Estudo da Relação entre Co-change Clusters e Interesses em Sistemas Opensource
# 8   Raciocínio Computacional no Ensino de Análise Combinatória e Probabilidade: o Uso da Linguagem de Programação R e do Construtivismo na Educação Básica
# 9   Formação docente e as práticas didáticas do professor de computação na educação profissional
# 10  Extração de Informação Pragmática em Documentos do Português do Brasil
# 11  Utilização da Robótica como Recurso Educacional para Reencanto da Educação: Uma Prática Possível
# 12  Sustentabilidade técnica de software acadêmico no domínio de ferramentas de análise estática de código-fonte
# 13  Investigating Feature-oriented Software Comprehension
# 14  MODELAGEM, BALANCEAMENTO DE CARGA E PREDIC ~AO DE FLUXOS NO PARADIGMA NEVOA DAS COISAS
# 15  REACHABLE WORKSPACE A PARTIR DE MÚLTIPLOS KINECTS PARA ANÁLISE DE MOVIMENTO DE PACIENTES HEMIPARÉTICOS
# 16  Auto-organização e Balanceamento de serviços na n´voa das coisas
# 17  Uma Plataforma para Descoberta, Implantação e Autoconfiguração de Serviços na Web das Coisas
# 18  Utilizando Features Linguísticas Genéricas para Classificação de Triplas Relacionais em Português, Inglês e Espanhol
# 19  Análise de Classificadores para Reconhecimento de Gestos 3D Dinâmicos da Mão Baseado em Descritores Geométricos
# 20  Cache Colaborativo e Distribuído como Suporte à Mobilidade de Produtores em Redes Sem Fio de Dados Nomeados
# 21  “A influência da metacomunicação na permanência ou no abandono em MOOC: uma investigação sob perspectiva semiótica”
# 22  “Uma Abordagem Unificada de Design para Modelagem Educacional e da Comunicação em MOOC”
# 23  “Uma Infraestrutura computacional para identificação e monitoramento de dívida técnica”
# 24  Degradação de Serviço com QoS Proporcional em Redes Ópticas
# 25  Localização de Conceitos Baseada em Microdomínios
# 26  Uma Heurística de Tolerância a Falhas para Redes de Backbone Ciente de Qualidade de Serviço e Sensível ao Contexto
# 27  Variability Based Approach to Generate and Disseminate Emergency Public Communications
# 28  Remoção de expressões faciais em imagens 3D para fins de reconhecimento
# 29  Intelligent colocation of HPC workloads for enhancing server efficiency
# 30  Agrupamento Flexível para Recomendação de Pontos de Interesse
# ... ...
# 55  USING CONTEXT TO SUPPORT TASK DISTRIBUTION IN MOBILE CROWDSOURCING
# 56  PRIMO: Um Modelo ICN de Prevenção a Ataques de Negação de Serviço por Inundação de Interesses Falsos.
# 57  INTEGRACÃO DE PRÁTICAS DO DDM AO PROCESSO ÁGIL : AVALIANDO ASPECTOS DE EVOLUCÃO DE SOFTWARE.
# 58  INTEGRAÇÃO E MINERAÇÃO VISUAL DE DADOS DE SAÚDE PÚBLICA: ESTUDO DE CASO EM MALÁRIA
# 59  AN APPROACH FOR RECOVERING ARCHITECTURAL VARIABILITY FROM SOURCE CODE
# 60  THE LEHMAN’S LAWS IN HIGHLY-CONFIGURABLE SYSTEMS: AN EMPIRICAL STUDY ON THE LINUX KERNEL VARIABLE FEATURES
# 61  RECONHECIMENTO DE IMPRESSOES DIGITAIS SOB VARIACÕES DE ESCALA PARA A IDENTIFICAÇÃO DE CRIANÇAS DESAPARECIDAS
# 62  Uma Abordagem Baseada em Programação Lógica por Restrições para o Problema de Escalonamento e Roteamento de Enfermeiras.
# 63  Clustering Categorical Data using the Frequency Factor
# 64  Towards an accurate energy forecast given uncertainties in Smart Grids
# 65  Matheuristics for the minimum weigthed feedback vertex set and b-coloring problems
# 66  SHARED RESOURCES IN MULTIPROCESSOR REAL-TIME SYSTEMS SCHEDULED BY RUN
# 67  Designing Smart City Mobile Applications: A Grounded Theory
# 68  Similaridade Semântica de Atributos para Dados em Nuvem : um estudo de caso no MIDAS
# 69  Uso de Redes de Função de Base Radial e Cadeias de Markov para detecção online de mudanças de conceito em fluxos contínuos de dados
# 70  Fuzzy Software Analyzer (FSA): Uma nova abordagem para interpretação de repositórios de versionamento de código-fonte
# 71  FEATURE INTERACTION EM AMBIENTES INTELIGENTES: UMA ABORDAGEM BASEADA NA ANÁLISE DOS DADOS
# 72  Process Smell : Um Catálogo de Bad Smells para Processos de Software”
# 73  “Feature Interactions in Highly Configurable Systems: A Dynamic Analysis Approach with  Varxplorer”
# 74  “(SPIDe Kids): adapting an interaction codesign process for deaf or hard of hearing children participation”
# 75  “A proposal of Data Interplay model for Internet of Things on Fog Computing paradigm”
# 76  “Prototyping and validating the CORA ontology and its reference architecture”
# 77  Gerenciamento de Mobilidade em Redes Veiculares de Dados Nomeados Baseado na Estabilidade do Enlace
# 78  Uma abordagem procedural para geração de terrenos planetários em multi-escala baseada em ruído fractal Browniano e tesselação
# 79  Autenticação Contínua de Indivíduos baseada em Algoritmos de Detecção de Anomalias
# 80  Avaliação empírica da geração automatizada de testes de software sob a perspectiva de Test Smells
